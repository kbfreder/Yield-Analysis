# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re

# %% [markdown]
# Import cleaned data:

# %%
df = pd.read_csv('BCS & BF results_cleaned.csv')

# %% [markdown]
# ## Let's start exploring the data!

# %% [markdown]
# Most entries with a note indicate an issue with the accuracy of the data

# %%
df[df['Notes'].notnull()]
# Out:
#           Batch ID  FV Volume  Total Yield %  BT Volume    DAW      DAW %  \
# 22      NB-LOD-038      399.0      85.714286     342.00   22.0   6.432749
# 43     LAW-SUN-065      315.0     108.253968     341.00    1.2   0.351906
# 44     LAW-SUP-028      314.0      96.019108     301.50   15.2   5.041459
# 53      TRB-OJ-005      290.0      78.103448     226.50   17.8   7.858720
# 63     TRB-HEF-050      328.0      60.975610     200.00    1.0   0.500000
# 68      SWA-SH-009      110.0      83.200000      91.52    3.5   3.824301
# 108      PK-FC-073      459.0      91.394336     419.50   10.9   2.598331
# 148      PK-SF-010      219.0      91.324201     200.00    7.0   3.500000
# 226     LR-SHT-034      210.0      92.857143     195.00    5.0   2.564103
# 280    TRB-R2R-137      517.0      85.106383     440.00   40.0   9.090909
# 292    TRB-PUM-001      481.0     130.956341     629.90  129.1  20.495317
# 355   ET-MLPIZ-001      224.0      79.955357     179.10    0.3   0.167504
# 518  TRB-20TON-004       74.0      80.405405      59.50    2.0   3.361345
# 520    TRB-WCS-063      236.0      91.949153     217.00    0.3   0.138249
# 529    TRB-R2R-152      571.0      90.350263     515.90   58.4  11.320023
# 531   TRB -R2R-153      549.0      86.921676     477.20   37.0   7.753562
# 538     TRB-OJ-024      311.0      73.247588     227.80   27.0  11.852502
# 539     TRB-OJ-025      102.0      98.333333     100.30    9.2   9.172483
#
#      Anticipated Yield  Packaged  discrepancy BT>Pack  discrepancy BT>Pack %  \
# 22               367.0    361.70                19.70               5.760234
# 43               300.0    294.60               -46.40             -13.607038
# 44               268.0    300.13                -1.37              -0.454395
# 53                 NaN    236.93                10.43               4.604857
# 63               295.0    184.93               -15.07              -7.535000
# 68                98.0     81.10               -10.42             -11.385490
# 108                NaN    401.73               -17.77              -4.235995
# 148              250.0    185.51               -14.49              -7.245000
# 226              189.0    188.35                -6.65              -3.410256
# 280              476.0    414.22               -25.78              -5.859091
# 292              650.0    522.41              -107.49             -17.064613
# 355                NaN       NaN              -179.10            -100.000000
# 518               67.6     74.98                15.48              26.016807
# 520              212.4    172.75               -44.25             -20.391705
# 529                NaN       NaN              -515.90            -100.000000
# 531              511.5    984.77               507.57             106.364208
# 538              281.1    226.98                -0.82              -0.359965
# 539               88.1     94.84                -5.46              -5.443669
#
#                                                  Notes      Brand Brewery  \
# 22             Centrifuge shut down; lost total # bbls     NB-LOD      NB
# 43                   ~300bbls dumped at FV by accident    LAW-SUN     LAW
# 44   MF did not record beer fence flow meter after ...    LAW-SUP     LAW
# 53   Separation was stopped and started, #'s may no...     TRB-OJ     TRB
# 63            Left 100bbls in FV to test FPS (planned)    TRB-HEF     TRB
# 68              BCS continued to count during post-run     SWA-SH     SWA
# 108       BBT overflowed during "empty surge tank"step      PK-FC      PK
# 148  Volume not 100% accurate; BCS skipped over emp...      PK-SF      PK
# 226        BBT overflowed, total volume is an estimate     LR-SHT      LR
# 280  BCS reset #'s during separation, volume not 10...    TRB-R2R     TRB
# 292   Could be as high as 700bbl and as low as 650 bbl    TRB-PUM     TRB
# 355  Total BBT volume not 100% accurate.  Issues wi...   ET-MLPIZ      ET
# 518    Stopped separation @57bbls to leave beer for A2  TRB-20TON     TRB
# 520                       22 BBLS used for FPS testing    TRB-WCS     TRB
# 529                             Blended with batch 153    TRB-R2R     TRB
# 531                             Blended with batch 152   TRB -R2R    TRB
# 538                             Blended with batch 025     TRB-OJ     TRB
# 539                             Blended with batch 024     TRB-OJ     TRB
#
#      Beer Volume  Beer Yield %  discrepancy Ant>BT  discrepancy Ant>BT %
# 22        320.00     80.200501               25.00              6.265664
# 43        339.80    107.873016              -41.00            -13.015873
# 44        286.30     91.178344              -33.50            -10.668790
# 53        208.70     71.965517                 NaN                   NaN
# 63        199.00     60.670732               95.00             28.963415
# 68         88.02     80.018182                6.48              5.890909
# 108       408.60     89.019608                 NaN                   NaN
# 148       193.00     88.127854               50.00             22.831050
# 226       190.00     90.476190               -6.00             -2.857143
# 280       400.00     77.369439               36.00              6.963250
# 292       500.80    104.116424               20.10              4.178794
# 355       178.80     79.821429                 NaN                   NaN
# 518        57.50     77.702703                8.10             10.945946
# 520       216.70     91.822034               -4.60             -1.949153
# 529       457.50     80.122592                 NaN                   NaN
# 531       440.20     80.182149               34.30              6.247723
# 538       200.80     64.565916               53.30             17.138264
# 539        91.10     89.313725              -12.20            -11.960784

# %% [markdown]
# Exclude these from our analysis

# %%
df = df[df['Notes'].isna()]
df.drop(['Notes'], axis =1, inplace=True)

# %% [markdown]
# Plot all numeric data for a broad overview:

# %%
num_data = df.select_dtypes(exclude=['object'])

# %%
num_data.hist(figsize=(20,20))

# %% [markdown]
# Could never figure out how to export this figure. Did a screen shot instead.

# %%
#fig = plt.gcf()
#fig = chart[0].get_figure()
#fig.savefig('histograms.png',transparent=False, dpi=80, bbox_inches="tight")
#plt.savefig('histograms.png')
#plt.get.savefig('histograms.png')

fig = plt.gcf()
fig.savefig('output.png',transparent=False, dpi=80)

# %%
df.dtypes
# Out:
# Batch ID                  object
# FV Volume                float64
# Total Yield %            float64
# BT Volume                float64
# DAW                      float64
# DAW %                    float64
# Anticipated Yield        float64
# Packaged                 float64
# discrepancy BT>Pack      float64
# discrepancy BT>Pack %    float64
# Notes                     object
# Brand                     object
# Brewery                   object
# Beer Volume              float64
# Beer Yield %             float64
# discrepancy Ant>BT       float64
# discrepancy Ant>BT %     float64
# dtype: object

# %% [markdown]
# Select a few to analyze further, and plot using MPL so we can modify & save the figure:

# %%
cols_to_hist=['Beer Yield %', 'Total Yield %', 'discrepancy Ant>BT', 'discrepancy Ant>BT %', 'discrepancy BT>Pack', 'discrepancy BT>Pack %']
data_to_hist =df[cols_to_hist]

# %%
fig = plt.figure(figsize = (10,12))
nrows = 3
ncols = 2

for i, col in enumerate(cols_to_hist):
    data = df[col].dropna()
    ax = fig.add_subplot(nrows,ncols,i+1)
    ax.hist(data)
    #ax.set_ylim(60,130)
    #ax.tick_params(bottom='off',labelbottom='off')
    ax.set_title(col)
    if re.search("%",col) is not None:
        ax.set_ylabel('%')
    else:
        ax.set_ylabel('bbls')

#fig.suptitle('Total Yield % for core TRB brands', fontsize = 14)

# %%
fig.savefig('histograms.png', transparent=False, dpi=80, bbox_inches="tight")

# %%
fig = plt.figure(figsize = (10,12))
nrows = 3
ncols = 2

for i, col in enumerate(cols_to_hist):
    data = df[col].dropna()
    ax = fig.add_subplot(nrows,ncols,i+1)
    ax.boxplot(data)
    #ax.set_ylim(60,103)
    #ax.tick_params(bottom='off',labelbottom='off')
    ax.set_title(col)
    if re.search("%",col) is not None:
        ax.set_ylabel('%')
    else:
        ax.set_ylabel('bbls')

#fig.suptitle('Total Yield % for core TRB brands', fontsize = 14)

# %%
fig.savefig('boxplots.png', transparent=False, dpi=80, bbox_inches="tight")

# %% [markdown]
# There appear to be some outliers, skewing the charts. Examine / remove those.

# %%
def clip_data_plot(col,limit):
    data = df[df[col].abs()<limit]
    fig = plt.figure(figsize=(5,8))
    
    ax1 = fig.add_subplot(211)
    ax1.hist(data[col].dropna())
    ax1.set_ylabel('# of batches')
    #ax1.get_xaxis().set_ticks([])
    
    ax2 = fig.add_subplot(212, sharex=ax1)
    ax2.boxplot(data[col].dropna(), vert=False)
    ax2.tick_params(left='off',labelleft='off')
    
    if re.search("%",col) is not None:
        ax2.set_xlabel('% difference')
    else:
        ax2.set_xlabel('bbls difference')
    
    fig.suptitle(col)
    #plt.show()

    print(data[col].describe())

# %%
col3 = 'discrepancy Ant>BT'
clip_data_plot(col3,100)
# Out:
# count    460.000000
# mean       3.372587
# std       20.248361
# min      -96.300000
# 25%       -4.600000
# 50%        3.300000
# 75%       12.425000
# max       95.000000
# Name: discrepancy Ant>BT, dtype: float64

# %%
col4 = 'discrepancy Ant>BT %'
clip_data_plot(col4,40)

# %%
col5 = 'discrepancy BT>Pack'
clip_data_plot(col5,100)

# %%
col6 = 'discrepancy BT>Pack %'
clip_data_plot(col6,40)
# Out:
# count    446.000000
# mean      -3.092058
# std        5.352776
# min      -27.221865
# 25%       -5.352713
# 50%       -2.973340
# 75%       -0.754977
# max       26.967655
# Name: discrepancy BT>Pack %, dtype: float64

# %%
col3 = 'Anticipated vs BT Volume'
data3 = df[df[col3].abs()< 100]
data3[col3].hist()

# %%
#df[df[col3].abs() > 50]

# %% [markdown]
# Pivot Table for data summary

# %%
cols_to_pivot = ['Total Yield %', 'DAW %', 'Anticipated vs Actual %', 'discrepancy BCS>Pack %', 'discrepancy BF>Pack %']

trb_pt = df[df['Brewery'] == 'TRB'].pivot_table(index=['Brand'], values = cols_to_pivot, aggfunc=[np.mean, np.std, np.min, np.max, len])

pt = df.pivot_table(index=['Brand'], values = cols_to_pivot, aggfunc=[np.mean, np.std, np.min, np.max, len])

trb_filt = trb_pt[trb_pt['len']['DAW %'] > 4]

pt_filt = pt[pt['len']['DAW %'] > 4]

# %% [markdown]
# # Two Roads Brands

# %%
brand_list = ['TRB-CBS','TRB-HEF','TRB-LH','TRB-OJ','TRB-PILS','TRB-R2R','TRB-WIPA','TRB-WCS']

# %% [markdown]
# Clip df to exclude obvious (?) outliers:

# %%
df.dtypes
# Out:
# Batch ID                  object
# FV Volume                float64
# Total Yield %            float64
# BT Volume                float64
# DAW                      float64
# DAW %                    float64
# Anticipated Yield        float64
# Packaged                 float64
# discrepancy BT>Pack      float64
# discrepancy BT>Pack %    float64
# Notes                     object
# Brand                     object
# Brewery                   object
# Beer Volume              float64
# Beer Yield %             float64
# discrepancy Ant>BT       float64
# discrepancy Ant>BT %     float64
# dtype: object

# %%
col3 = 'discrepancy Ant>BT'
col4 = 'discrepancy Ant>BT %'
col5 = 'discrepancy BT>Pack'
col6 = 'discrepancy BT>Pack %'

# %%
df = df[(df[col3].abs() < 100) & (df[col5].abs() <100) & (df[col4]<40) & (df[col6]<40)]

# %%
fig = plt.figure(figsize = (20,8))
nrows = 2
ncols = 4
col_to_plot = 'Total Yield %'

for i, brand in enumerate(brand_list):
    data = df[df['Brand'] == brand][col_to_plot]
    ax = fig.add_subplot(nrows,ncols,i+1)
    ax.boxplot(data)
    ax.set_ylim(70,105)
    ax.tick_params(bottom='off',labelbottom='off')
    ax.set_title(brand)

fig.suptitle(col_to_plot + ' for core TRB brands', fontsize = 14)
# Out:
# Text(0.5,0.98,'Total Yield % for core TRB brands')

# %%
fig.savefig('trb total yields.png', transparent=False, dpi=80, bbox_inches="tight")

# %%
fig = plt.figure(figsize = (20,8))
nrows = 2
ncols = 4
col_to_plot = 'Total Yield %'

for i, brand in enumerate(brand_list):
    data = df[df['Brand'] == brand][col_to_plot]
    ax = fig.add_subplot(nrows,ncols,i+1)
    ax.hist(data)
    ax.set_xlim(70,105)
    #ax.tick_params(bottom='off',labelbottom='off')
    ax.set_title(brand)

fig.suptitle(col_to_plot + ' for core TRB brands', fontsize = 14)
# Out:
# Text(0.5,0.98,'Total Yield % for core TRB brands')

# %%
fig.savefig('trb total yields - hist.png', transparent=False, dpi=80, bbox_inches="tight")

# %%
fig = plt.figure(figsize = (20,8))
nrows = 2
ncols = 4
col_to_plot = col3

for i, brand in enumerate(brand_list):
    data = df[df['Brand'] == brand][col_to_plot].dropna()
    ax = fig.add_subplot(nrows,ncols,i+1)
    ax.boxplot(data)
    ax.set_ylim(-45,100)
    ax.tick_params(bottom='off',labelbottom='off')
    ax.set_title(brand)
    ax.axhline(y=0, color='b',linewidth=1)
    
    if i in (0,4):
        ax.set_ylabel('bbls')

fig.suptitle(col_to_plot + ' for core TRB brands', fontsize = 14)
# Out:
# Text(0.5,0.98,'discrepancy Ant>BT for core TRB brands')

# %%
fig.savefig('trb ant vs bt vol bbls box.png', transparent=False, dpi=80, bbox_inches="tight")

# %%
fig = plt.figure(figsize = (20,8))
nrows = 2
ncols = 4
col_to_plot = col4

for i, brand in enumerate(brand_list):
    data = df[df['Brand'] == brand][col_to_plot].dropna()
    ax = fig.add_subplot(nrows,ncols,i+1)
    ax.boxplot(data)
    ax.set_ylim(-15,20)
    ax.tick_params(bottom='off',labelbottom='off')
    ax.set_title(brand)
    ax.axhline(y=0, color='b',linewidth=1)
    
    if i in (0,4):
        ax.set_ylabel('%')

fig.suptitle(col_to_plot + ' for core TRB brands', fontsize = 14)
# Out:
# Text(0.5,0.98,'discrepancy Ant>BT % for core TRB brands')

# %%
fig.savefig('trb anticipate vs bt yields % box.png', transparent=False, dpi=80, bbox_inches="tight")

# %%
fig = plt.figure(figsize = (20,8))
nrows = 2
ncols = 4
col_to_plot = col5

for i, brand in enumerate(brand_list):
    data = df[df['Brand'] == brand][col_to_plot].dropna()
    ax = fig.add_subplot(nrows,ncols,i+1)
    ax.hist(data)
    ax.set_xlim(-20,20)
    #ax.tick_params(bottom='off',labelbottom='off')
    ax.set_title(brand)
    ax.axvline(x=0, color='r',linewidth=1)

fig.suptitle(col_to_plot + ' for core TRB brands', fontsize = 14)
# Out:
# Text(0.5,0.98,'discrepancy BT>Pack for core TRB brands')

# %%
fig.savefig('trb anticipated vs bt yields % - hist.png', transparent=False, dpi=80, bbox_inches="tight")

# %%
def hist_and_boxplot(col,brand):
    '''(col, brand) --> histogram & boxplot
    '''
    data = df[df['Brand'] == brand][col].dropna()
    fig = plt.figure(figsize=(5,8))
    
    ax1 = fig.add_subplot(211)
    ax1.hist(data)
    ax1.set_ylabel('# of batches')
    #ax1.get_xaxis().set_ticks([])
    
    ax2 = fig.add_subplot(212, sharex=ax1)
    ax2.boxplot(data, vert=False)
    ax2.tick_params(left='off',labelleft='off')
    
    if re.search("%",col) is not None:
        ax2.set_xlabel('% difference')
    else:
        ax2.set_xlabel('bbls difference')
    
    fig.suptitle(brand + ": " + col)
    #plt.show()

    print(data.describe())

# %%
hist_and_boxplot(col5,'TRB-R2R')
# Out:
# count    29.000000
# mean    -11.081172
# std      18.254170
# min     -89.720000
# 25%     -14.340000
# 50%      -6.904000
# 75%      -2.400000
# max       9.800000
# Name: discrepancy BT>Pack, dtype: float64

# %%
hist_and_boxplot(col6,'TRB-R2R')
# Out:
# count    29.000000
# mean     -3.875652
# std       5.246177
# min     -18.900358
# 25%      -5.411190
# 50%      -2.653950
# 75%      -0.931315
# max       2.183353
# Name: discrepancy BT>Pack %, dtype: float64

# %%
cols_to_hist
# Out:
# ['Beer Yield %',
#  'Total Yield %',
#  'discrepancy Ant>BT',
#  'discrepancy Ant>BT %',
#  'discrepancy BT>Pack',
#  'discrepancy BT>Pack %']

# %%
def all_the_plots(brand):
    '''(col, brand) --> histogram & boxplot
    '''
    #data = df[df['Brand'] == brand][col].dropna()
    
    fig = plt.figure(figsize=(24,6))
    
    for i, col in enumerate(cols_to_hist):
        data = df[df['Brand'] == brand][col].dropna()
        ax1 = fig.add_subplot(2,6,i+1)
        ax1.hist(data)
        ax1.set_ylabel('# of batches')
        #ax1.get_xaxis().set_ticks([])
        ax1.set_title(col)
        
        ax2 = fig.add_subplot(2,6,i+7, sharex=ax1)
        ax2.boxplot(data, vert=False)
        ax2.tick_params(left='off',labelleft='off')
    
        if re.search("%",col) is not None:
            ax2.set_xlabel('% difference')
        else:
            ax2.set_xlabel('bbls difference')
        
    
    fig.suptitle(brand, fontsize=20)

# %%
all_the_plots('TRB-R2R')

# %%
for brand in brand_list:
    all_the_plots(brand)

# %%
df.dtypes
# Out:
# Batch ID                  object
# FV Volume                float64
# Total Yield %            float64
# BT Volume                float64
# DAW                      float64
# DAW %                    float64
# Anticipated Yield        float64
# Packaged                 float64
# discrepancy BT>Pack      float64
# discrepancy BT>Pack %    float64
# Notes                     object
# Brand                     object
# Brewery                   object
# Beer Volume              float64
# Beer Yield %             float64
# discrepancy Ant>BT       float64
# discrepancy Ant>BT %     float64
# dtype: object

# %% [markdown]
# ## Batch Size

# %%
data = df['FV Volume']
binwidth = 25
num_bins=np.arange(min(data), max(data) + binwidth, binwidth)
plt.hist(data, bins = num_bins)
# Out:
# (array([  2., 108.,  97.,   3.,  12.,  26.,  30.,   4.,  10.,  61.,  95.,
#           5.,   1.,   2.,   4.,   8.,   0.,   1.,   4.,  18.,  19.,   5.,
#          23.,  15.,   2.,   2.,   2.]),
#  array([ 60.,  85., 110., 135., 160., 185., 210., 235., 260., 285., 310.,
#         335., 360., 385., 410., 435., 460., 485., 510., 535., 560., 585.,
#         610., 635., 660., 685., 710., 735.]),
#  <a list of 27 Patch objects>)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

def apply_colors(vol):
    if vol in range(0,120):
        color = '#f97306'  #orange
    elif vol in range(150,240):
        color = '#029386'  #teal
    elif vol in range(241, 350):
        color = '#06c2ac'  #turquoise
    elif vol in range(351,455):
        color = '#aaa662'   #khaki
    elif vol in range(456,575):
        color = '#8eab12'   #pea green
    else:
        color = '#6e750e'  #olive

    return color

#color_legend = {keys = ['orange', 'teal', 'turquoise','khaki', 'pea grean', 'olive'],
 #              values = ['#f97306', '#029386','06c2ac', '#aaa662', '#8eab12', '#6e750e']}


color_list = ['#f97306', '#029386','06c2ac', '#aaa662', '#8eab12', '#6e750e']

    
colors = df['FV Volume'].apply(apply_colors)
        
ax.scatter(x=df['FV Volume'], y=df['Total Yield %'], color = colors, alpha=0.4)
ax.set_xlabel('FV Volume (bbls)')
ax.set_ylabel('Total Yield (%) to BT')
# Out:
# Text(0,0.5,'Total Yield (%) to BT')

# %%
fig.savefig('fv vol vs total yield % - scatter with color.png', transparent=False, dpi=80, bbox_inches="tight")

# %%
df[df['Brand'] == 'TRB-R2R']
# Out:
#         Batch ID  FV Volume  Total Yield %  BT Volume    DAW      DAW %  \
# 1    TRB-R2R-122      566.0      82.862191      469.0  43.80   9.339019
# 21   TRB-R2R-124      266.0     106.240602      282.6  17.70   6.263270
# 24   TRB-R2R-123      573.0      90.977312      521.3  45.30   8.689814
# 40   TRB-R2R-125      575.0      88.121739      506.7  39.55   7.805408
# 64   TRB-R2R-126      570.0      85.842105      489.3  47.80   9.769058
# 76   TRB-R2R-127       88.0      90.909091       80.0   5.70   7.125000
# 102  TRB-R2R-128      580.0      85.879310      498.1  40.80   8.191126
# 114  TRB-R2R-129      286.0      86.573427      247.6  16.60   6.704362
# 124  TRB-R2R-130      293.0      90.887372      266.3  20.40   7.660533
# 164  TRB-R2R-131      293.0      88.771331      260.1  19.30   7.420223
# 176  TRB-R2R-132      580.0      89.741379      520.5  48.40   9.298751
# 188  TRB-R2R-133      282.0      84.290780      237.7  11.80   4.964241
# 195  TRB-R2R-134      285.0      90.421053      257.7  17.00   6.596818
# 214  TRB-R2R-135      540.0      88.611111      478.5  36.60   7.648903
# 237  TRB-R2R-136      538.0      89.814126      483.2  27.00   5.587748
# 289  TRB-R2R-138      262.0      90.725191      237.7  17.90   7.530501
# 325  TRB-R2R-139      561.0      86.595365      485.8  37.30   7.678057
# 343  TRB-R2R-140      453.0      72.317881      327.6  25.10   7.661783
# 359  TRB-R2R-141      281.0      88.113879      247.6  17.60   7.108239
# 380  TRB-R2R-142      544.0      87.261029      474.7  51.70  10.891089
# 398  TRB-R2R-143      570.0      84.614035      482.3  43.90   9.102219
# 412  TRB-R2R-144      184.0      90.869565      167.2  15.40   9.210526
# 430  TRB-R2R-145      539.0      91.632653      493.9  44.30   8.969427
# 444  TRB-R2R-146      452.0      90.641593      409.7  29.90   7.298023
# 464  TRB-R2R-147       97.0      90.515464       87.8   4.50   5.125285
# 481  TRB-R2R-148      559.0      76.332737      426.7  16.20   3.796578
# 499  TRB-R2R-149      289.0      89.653979      259.1  16.70   6.445388
# 502  TRB-R2R-150      193.0      79.637306      153.7  11.10   7.221861
# 508  TRB-R2R-151      185.0      89.621622      165.8  15.70   9.469240
# 547  TRB-R2R-154      278.0      92.589928      257.4  32.30  12.548563
# 559  TRB-R2R-155      543.0      87.182320      473.4  53.50  11.301225
# 572  TRB-R2R-156      450.0      81.000000      364.5  46.00  12.620027
#
#      Anticipated Yield  Packaged  discrepancy BT>Pack  discrepancy BT>Pack %  \
# 1                533.0   471.000                2.000               0.426439
# 21               254.0   246.800              -35.800             -12.668082
# 24               519.0   531.100                9.800               1.879916
# 40               520.0   504.900               -1.800              -0.355240
# 64               523.0   475.240              -14.060              -2.873493
# 76                86.0    75.460               -4.540              -5.675000
# 102              524.0   477.230              -20.870              -4.189922
# 114              267.0   237.060              -10.540              -4.256866
# 124              275.0   251.890              -14.410              -5.411190
# 164              265.0   255.370               -4.730              -1.818531
# 176              525.0   513.596               -6.904              -1.326417
# 188              246.0   229.960               -7.740              -3.256205
# 195              264.0   255.300               -2.400              -0.931315
# 214              488.0   464.160              -14.340              -2.996865
# 237              480.0   477.720               -5.480              -1.134106
# 289              241.0   237.250               -0.450              -0.189314
# 325                NaN       NaN             -485.800            -100.000000
# 343                NaN       NaN             -327.600            -100.000000
# 359              260.0   225.410              -22.190              -8.962036
# 380              519.0   384.980              -89.720             -18.900358
# 398              517.0   469.500              -12.800              -2.653950
# 412              181.0   164.610               -2.590              -1.549043
# 430              533.0   496.820                2.920               0.591213
# 444              432.0   404.200               -5.500              -1.342446
# 464               89.0    73.710              -14.090             -16.047836
# 481              505.0   435.630                8.930               2.092805
# 499              275.0   256.030               -3.070              -1.184871
# 502              181.0   135.430              -18.270             -11.886792
# 508              179.0   169.420                3.620               2.183353
# 547              260.6   246.850              -10.550              -4.098679
# 559                NaN       NaN             -473.400            -100.000000
# 572                NaN       NaN             -364.500            -100.000000
#
#        Brand Brewery  Beer Volume  Beer Yield %  discrepancy Ant>BT  \
# 1    TRB-R2R     TRB       425.20     75.123675                64.0
# 21   TRB-R2R     TRB       264.90     99.586466               -28.6
# 24   TRB-R2R     TRB       476.00     83.071553                -2.3
# 40   TRB-R2R     TRB       467.15     81.243478                13.3
# 64   TRB-R2R     TRB       441.50     77.456140                33.7
# 76   TRB-R2R     TRB        74.30     84.431818                 6.0
# 102  TRB-R2R     TRB       457.30     78.844828                25.9
# 114  TRB-R2R     TRB       231.00     80.769231                19.4
# 124  TRB-R2R     TRB       245.90     83.924915                 8.7
# 164  TRB-R2R     TRB       240.80     82.184300                 4.9
# 176  TRB-R2R     TRB       472.10     81.396552                 4.5
# 188  TRB-R2R     TRB       225.90     80.106383                 8.3
# 195  TRB-R2R     TRB       240.70     84.456140                 6.3
# 214  TRB-R2R     TRB       441.90     81.833333                 9.5
# 237  TRB-R2R     TRB       456.20     84.795539                -3.2
# 289  TRB-R2R     TRB       219.80     83.893130                 3.3
# 325  TRB-R2R     TRB       448.50     79.946524                 NaN
# 343  TRB-R2R     TRB       302.50     66.777042                 NaN
# 359  TRB-R2R     TRB       230.00     81.850534                12.4
# 380  TRB-R2R     TRB       423.00     77.757353                44.3
# 398  TRB-R2R     TRB       438.40     76.912281                34.7
# 412  TRB-R2R     TRB       151.80     82.500000                13.8
# 430  TRB-R2R     TRB       449.60     83.413729                39.1
# 444  TRB-R2R     TRB       379.80     84.026549                22.3
# 464  TRB-R2R     TRB        83.30     85.876289                 1.2
# 481  TRB-R2R     TRB       410.50     73.434705                78.3
# 499  TRB-R2R     TRB       242.40     83.875433                15.9
# 502  TRB-R2R     TRB       142.60     73.886010                27.3
# 508  TRB-R2R     TRB       150.10     81.135135                13.2
# 547  TRB-R2R     TRB       225.10     80.971223                 3.2
# 559  TRB-R2R     TRB       419.90     77.329650                 NaN
# 572  TRB-R2R     TRB       318.50     70.777778                 NaN
#
#      discrepancy Ant>BT %
# 1               11.307420
# 21             -10.751880
# 24              -0.401396
# 40               2.313043
# 64               5.912281
# 76               6.818182
# 102              4.465517
# 114              6.783217
# 124              2.969283
# 164              1.672355
# 176              0.775862
# 188              2.943262
# 195              2.210526
# 214              1.759259
# 237             -0.594796
# 289              1.259542
# 325                   NaN
# 343                   NaN
# 359              4.412811
# 380              8.143382
# 398              6.087719
# 412              7.500000
# 430              7.254174
# 444              4.933628
# 464              1.237113
# 481             14.007156
# 499              5.501730
# 502             14.145078
# 508              7.135135
# 547              1.151079
# 559                   NaN
# 572                   NaN

# %%
df[df['Brand'] == 'TRB-R2R']['FV Volume'] / 94.0
# Out:
# 1      6.021277
# 21     2.829787
# 24     6.095745
# 40     6.117021
# 64     6.063830
# 76     0.936170
# 102    6.170213
# 114    3.042553
# 124    3.117021
# 164    3.117021
# 176    6.170213
# 188    3.000000
# 195    3.031915
# 214    5.744681
# 237    5.723404
# 289    2.787234
# 325    5.968085
# 343    4.819149
# 359    2.989362
# 380    5.787234
# 398    6.063830
# 412    1.957447
# 430    5.734043
# 444    4.808511
# 464    1.031915
# 481    5.946809
# 499    3.074468
# 502    2.053191
# 508    1.968085
# 547    2.957447
# 559    5.776596
# 572    4.787234
# Name: FV Volume, dtype: float64

# %% [markdown]
# ### Assign batch size based on volume (we don't have tank info):

# %%
b100 = 125
b200 = 249
b300 = 349
b400 = 449
b500 = 549

def assign_batch_size(vol):
    if vol in range(0,b100):
        color = '#f97306'  #orange
        batch_size = 100
    elif vol in range(b100+1,b200):
        color = '#029386'  #teal
        batch_size = 200
    elif vol in range(b200+1,b300):
        color = '#06c2ac'  #turquoise
        batch_size = 300
    elif vol in range(b300+1,b400):
        color = '#aaa662'   #khaki
        batch_size = 400
    elif vol in range(b400+1,b500):
        color = '#8eab12'   #pea green
        batch_size = 500
    else:
        color = '#6e750e'  #olive
        batch_size = 600

    return batch_size

# %%
pr_list = [0,b100,b200,b300,b400,b500,777]

for i in range(1,7):
    print (str(i*100) +"-bbl = " + str(pr_list[i-1]) + " - " + str(pr_list[i]))
# Out:
# 100-bbl = 0 - 125
# 200-bbl = 125 - 249
# 300-bbl = 249 - 349
# 400-bbl = 349 - 449
# 500-bbl = 449 - 549
# 600-bbl = 549 - 777

# %%
df['Batch Size'] = df['FV Volume'].apply(assign_batch_size)

# %%
r2r_batch_size_data = []
    
for i in range(1,7):
    batch_size_data.append(df[(df['Batch Size'] == i*100) & (df['Brand'] == brand)])

# %%
fig = plt.figure(figsize = (20,4))

for i, data in enumerate(r2r_batch_size_data):
    data_to_plot = data[ycol]
    
    ax1 = fig.add_subplot(1,6,i+1)
    ax1.set_ylim(60,120)
    ax1.set_xlim(0.7,1.3)
    for spine in ax1.spines.values():
        spine.set_visible(False)
    ax1.tick_params(bottom='off', left='off', labelleft='off', labelbottom='off')
    ax1.set_title(str((i+1)*100) + "-bbl", y=1.05)
    ax1.text(1,70,'n = ' + str(len(data_to_plot)),horizontalalignment='center', fontsize=12)
    
    if i == 0:
        ax1.tick_params(labelleft='on')
        ax1.set_ylabel('% Yield')
        ax1.axhline(y=100, color='black',linewidth=1, xmin=0.1, xmax = 1.1, clip_on=False)
    elif i == len(batch_size_data)-1:
        ax1.axhline(y=100, color='black',linewidth=1, xmin=-0.1, xmax=1, clip_on=False)
    else:
        ax1.axhline(y=100, color='black',linewidth=1, xmin=-0.1, xmax = 1.1, clip_on=False)
    

    
    if len(data) != 0:
        vp = ax1.violinplot(data_to_plot, showmeans=True)

        
        ax1.axhline(y=100, color='black',linewidth=1)
        #ax1.set_axis_off()
        
        ax1.text(1,65,'mean = ' + "{:.2f}".format(np.mean(data_to_plot)),horizontalalignment='center', fontsize=12)
        ax1.text(1,60,'std dev = ' + "{:.2f}".format(np.std(data_to_plot)),horizontalalignment='center', fontsize=12)
        #ax1.text(1,70,'n = ' + str(len(data_to_plot)),horizontalalignment='center', fontsize=12)
        vp['cmeans'].set_edgecolor('orange')
    
    
    
fig.suptitle('Total Yield (%) by batch size for TRB-R2R',fontsize=16, y=1.1)
# Out:
# Text(0.5,1.1,'Total Yield (%) by batch size for TRB-R2R')

# %%
fig.savefig('R2R total yield % by batch size - violin', transparent=False, dpi=80, bbox_inches="tight")

# %%
batch_size_pivot = df.pivot_table(index=['Brand','Batch Size'], values=['Total Yield %'], aggfunc=[len, np.mean, np.std, np.min, np.max])

# %%
batch_size_pivot.to_csv('yield by batch size.csv')
#lg_num.to_csv('')

# %%
def plot_data_brand_bsize(brand):
    
    batch_size_data = []
    
    for i in range(1,7):
        batch_size_data.append(df[(df['Batch Size'] == i*100) & (df['Brand'] == brand)])
    
    fig = plt.figure(figsize = (20,4))

    for i, data in enumerate(batch_size_data):
        data_to_plot = data[ycol]

        ax1 = fig.add_subplot(1,6,i+1)
        ax1.set_ylim(60,120)
        ax1.set_xlim(0.7,1.3)
        for spine in ax1.spines.values():
            spine.set_visible(False)
        ax1.tick_params(bottom='off', left='off', labelleft='off', labelbottom='off')
        ax1.set_title(str((i+1)*100) + "-bbl", y=1.05)
        ax1.text(1,70,'n = ' + str(len(data_to_plot)),horizontalalignment='center', fontsize=12)

        if i == 0:
            ax1.tick_params(labelleft='on')
            ax1.set_ylabel('% Yield')
            ax1.axhline(y=100, color='black',linewidth=1, xmin=0.1, xmax = 1.1, clip_on=False)
        elif i == len(batch_size_data)-1:
            ax1.axhline(y=100, color='black',linewidth=1, xmin=-0.1, xmax=1, clip_on=False)
        else:
            ax1.axhline(y=100, color='black',linewidth=1, xmin=-0.1, xmax = 1.1, clip_on=False)

        if len(data) != 0:
            vp = ax1.violinplot(data_to_plot, showmeans=True)
            ax1.axhline(y=100, color='black',linewidth=1)
            ax1.text(1,65,'mean = ' + "{:.2f}".format(np.mean(data_to_plot)),horizontalalignment='center', fontsize=12)
            ax1.text(1,60,'std dev = ' + "{:.2f}".format(np.std(data_to_plot)),horizontalalignment='center', fontsize=12)
            vp['cmeans'].set_edgecolor('orange')

    fig.suptitle('Total Yield (%) by batch size for ' + brand,fontsize=16, y=1.1)
    
    fig.savefig(brand + ' total yield % by batch size - violin', transparent=False, dpi=80, bbox_inches="tight")

# %%
plot_data_brand_bsize('LAW-SUN')

# %%
res = df['Brand'].value_counts()
brands_hi_vol = res[res > 8].index.tolist()
brands_hi_vol

# %%
for br in brands_hi_vol:
    plot_data_brand_bsize(br)
